# %% [markdown]
# # Import Library

# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import missingno as msn
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set()
from datetime import date, timedelta, datetime

# %% [markdown]
# # Extract Data

# %%
df=pd.read_csv(r'dataset/Airplane_Crashes_and_Fatalities_Since_1908.csv')

# %% [markdown]
# ### Lihat 5 Data Teratas

# %%
df.head(5)
# Out:
#          Date   Time                            Location  \
# 0   9/17/1908  17:18                 Fort Myer, Virginia
# 1   7/12/1912   6:30             AtlantiCity, New Jersey
# 2    8/6/1913    NaN  Victoria, British Columbia, Canada
# 3    9/9/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator Flight #          Route                    Type  \
# 0    Military - U.S. Army      NaN  Demonstration        Wright Flyer III
# 1    Military - U.S. Navy      NaN    Test flight               Dirigible
# 2                 Private        -            NaN        Curtiss seaplane
# 3  Military - German Navy      NaN            NaN  Zeppelin L-1 (airship)
# 4  Military - German Navy      NaN            NaN  Zeppelin L-2 (airship)
#
#   Registration cn/In  Aboard  Fatalities  Ground  \
# 0          NaN     1     2.0         1.0     0.0
# 1          NaN   NaN     5.0         5.0     0.0
# 2          NaN   NaN     1.0         1.0     0.0
# 3          NaN   NaN    20.0        14.0     0.0
# 4          NaN   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %% [markdown]
# ### Lihat Shape Data (Jumlah Row, Column)

# %%
df.shape
# Out:
# (5268, 13)

# %% [markdown]
# ### Cek Data Null

# %%
df.isnull().sum()
# Out:
# Date               0
# Time            2219
# Location          20
# Operator          18
# Flight #        4199
# Route           1706
# Type              27
# Registration     335
# cn/In           1228
# Aboard            22
# Fatalities        12
# Ground            22
# Summary          390
# dtype: int64

# %% [markdown]
# ### Menghitung Presentasi Untuk Memutuskan Kolom Mana yang Akan Dihapus

# %%
df.isnull().sum()/df.shape[0]
# Out:
# Date            0.000000
# Time            0.421222
# Location        0.003797
# Operator        0.003417
# Flight #        0.797077
# Route           0.323842
# Type            0.005125
# Registration    0.063591
# cn/In           0.233106
# Aboard          0.004176
# Fatalities      0.002278
# Ground          0.004176
# Summary         0.074032
# dtype: float64

# %% [markdown]
# ### Kolom Dihapus Jika Presentase >50%

# %%
df.drop('Flight #', axis=1,inplace=True)

# %%
df['Ground'].value_counts()
# Out:
# 0.0       5027
# 1.0         53
# 2.0         27
# 3.0         21
# 4.0         15
# 5.0         10
# 8.0         10
# 7.0          8
# 11.0         6
# 6.0          6
# 22.0         5
# 13.0         4
# 24.0         3
# 10.0         3
# 44.0         3
# 20.0         3
# 14.0         2
# 2750.0       2
# 30.0         2
# 12.0         2
# 19.0         2
# 47.0         2
# 52.0         2
# 70.0         2
# 54.0         1
# 18.0         1
# 45.0         1
# 16.0         1
# 35.0         1
# 50.0         1
# 23.0         1
# 225.0        1
# 125.0        1
# 75.0         1
# 15.0         1
# 32.0         1
# 49.0         1
# 9.0          1
# 40.0         1
# 36.0         1
# 113.0        1
# 107.0        1
# 33.0         1
# 87.0         1
# 31.0         1
# 63.0         1
# 17.0         1
# 37.0         1
# 58.0         1
# 85.0         1
# Name: Ground, dtype: int64

# %%
df.nunique()
# Out:
# Date            4753
# Time             999
# Location        4303
# Operator        2476
# Route           3244
# Type            2446
# Registration    4903
# cn/In           3638
# Aboard           239
# Fatalities       191
# Ground            50
# Summary         4673
# dtype: int64

# %% [markdown]
# Melihat std,min,max,mean

# %%
df.describe().T
# Out:
#              count       mean        std  min  25%   50%   75%     max
# Aboard      5246.0  27.554518  43.076711  0.0  5.0  13.0  30.0   644.0
# Fatalities  5256.0  20.068303  33.199952  0.0  3.0   9.0  23.0   583.0
# Ground      5246.0   1.608845  53.987827  0.0  0.0   0.0   0.0  2750.0

# %%
df.head(5)
# Out:
#          Date   Time                            Location  \
# 0   9/17/1908  17:18                 Fort Myer, Virginia
# 1   7/12/1912   6:30             AtlantiCity, New Jersey
# 2    8/6/1913    NaN  Victoria, British Columbia, Canada
# 3    9/9/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
df['Aboard'].value_counts().mean()
# Out:
# 21.94979079497908

# %%
df['Aboard'].nunique()
# Out:
# 239

# %%
df['Location'].value_counts()
# Out:
# Sao Paulo, Brazil                    15
# Moscow, Russia                       15
# Rio de Janeiro, Brazil               14
# Anchorage, Alaska                    13
# Manila, Philippines                  13
#                                      ..
# Near Charana, Bolivia                 1
# Monte Matto, Italy                    1
# Misaki Mountain, Japan                1
# Angelholm, Sweden                     1
# State of Arunachal Pradesh, India     1
# Name: Location, Length: 4303, dtype: int64

# %%
df.head()
# Out:
#          Date   Time                            Location  \
# 0   9/17/1908  17:18                 Fort Myer, Virginia
# 1   7/12/1912   6:30             AtlantiCity, New Jersey
# 2    8/6/1913    NaN  Victoria, British Columbia, Canada
# 3    9/9/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
df[(df['Location']=='Sao Paulo, Brazil')][['Location','Summary']]
# Out:
#                Location                                            Summary
# 469   Sao Paulo, Brazil           The mail plane crashed while taking off.
# 664   Sao Paulo, Brazil                                    Crashed in fog.
# 836   Sao Paulo, Brazil  Crashed into the Solimoes extension of the Ama...
# 1148  Sao Paulo, Brazil  Crashed into a house shortly after taking off ...
# 1203  Sao Paulo, Brazil  Crashed while attempting to make an emergency ...
# 1269  Sao Paulo, Brazil  Crashed while on final approach to Sao Paulo. ...
# 1327  Sao Paulo, Brazil  The cargo plane crashed on takeoff. Elevator l...
# 1406  Sao Paulo, Brazil                                Crashed on takeoff.
# 1619  Sao Paulo, Brazil  Crashed a few minutes after taking off from Sa...
# 1828  Sao Paulo, Brazil  The crippled airliner crashed into houses and ...
# 1848  Sao Paulo, Brazil  The aircraft returned to airport after the No....
# 3601  Sao Paulo, Brazil  The crew accidently tried to take off from a t...
# 4406  Sao Paulo, Brazil  The crew was advised they were too high and fa...
# 5159  Sao Paulo, Brazil  The jet airliner crashed while attempting to l...
# 5177  Sao Paulo, Brazil  The executive jet took off, banked to the righ...

# %%
df[(df['Fatalities']>20) & (df['Location']=='Sao Paulo, Brazil')]
# Out:
#             Date   Time           Location         Operator  \
# 1406  12/19/1955    NaN  Sao Paulo, Brazil  Cruzeiro Do Sud
# 1848    5/3/1963    NaN  Sao Paulo, Brazil         Cruzeiro
# 5159   7/17/2007  18:52  Sao Paulo, Brazil     TAM (Brazil)
#
#                            Route               Type Registration cn/In  \
# 1406           Sao Paulo - Belem       Douglas DC-3          NaN   NaN
# 1848  Sao Paulo - Rio de Janeiro  Convair CV-340-59       PP-CDW   159
# 5159    Porto Alegre - Sao Paulo   Airbus A-320-233       PR-MBK   789
#
#       Aboard  Fatalities  Ground  \
# 1406    26.0        26.0     0.0
# 1848    50.0        37.0     0.0
# 5159   187.0       187.0    12.0
#
#                                                 Summary
# 1406                                Crashed on takeoff.
# 1848  The aircraft returned to airport after the No....
# 5159  The jet airliner crashed while attempting to l...

# %%
df.head(5)
# Out:
#          Date   Time                            Location  \
# 0   9/17/1908  17:18                 Fort Myer, Virginia
# 1   7/12/1912   6:30             AtlantiCity, New Jersey
# 2    8/6/1913    NaN  Victoria, British Columbia, Canada
# 3    9/9/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
df.plot(x="Aboard", y="Fatalities", kind="scatter")
plt.show()

# %%
df.head()
# Out:
#          Date   Time                            Location  \
# 0   9/17/1908  17:18                 Fort Myer, Virginia
# 1   7/12/1912   6:30             AtlantiCity, New Jersey
# 2    8/6/1913    NaN  Victoria, British Columbia, Canada
# 3    9/9/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary
# 0  During a demonstration flight, a U.S. Army fly...
# 1  First U.S. dirigible Akron exploded just offsh...
# 2  The first fatal airplane accident in Canada oc...
# 3  The airship flew into a thunderstorm and encou...
# 4  Hydrogen gas which was being vented was sucked...

# %%
df['Route'].value_counts()
# Out:
# Training                      81
# Sightseeing                   29
# Test flight                   17
# Test                           6
# Sao Paulo - Rio de Janeiro     5
#                               ..
# Manila - Lapu Lapu             1
# Saint Denis - Paris            1
# Cork - London                  1
# Peoria, IL - St. Louis, MO     1
# Mechuka for Jorhat             1
# Name: Route, Length: 3244, dtype: int64

# %%
df['Time'] = df['Time'].str.replace('c: ', '')
df['Time'] = df['Time'].str.replace('c:', '')
df['Time'] = df['Time'].str.replace('c', '')
df['Time'] = df['Time'].str.replace('12\'20', '12:20')
df['Time'] = df['Time'].str.replace('18.40', '18:40')
df['Time'] = df['Time'].str.replace('0943', '09:43')
df['Time'] = df['Time'].str.replace('22\'08', '22:08')
df['Time'] = df['Time'].str.replace('114:20', '00:00')

# %% [markdown]
# 'Time' column has NaN so we are going to fillna

# %%
df['Time'] = df['Time'].fillna('00:00')

# %% [markdown]
# multiply two columns to create another one

# %%
df['DateTime'] = df['Date'] + ' ' + df['Time']

# %%
df.head()
# Out:
#          Date   Time                            Location  \
# 0   9/17/1908  17:18                 Fort Myer, Virginia
# 1   7/12/1912   6:30             AtlantiCity, New Jersey
# 2    8/6/1913  00:00  Victoria, British Columbia, Canada
# 3    9/9/1913  18:30                  Over the North Sea
# 4  10/17/1913  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary          DateTime
# 0  During a demonstration flight, a U.S. Army fly...   9/17/1908 17:18
# 1  First U.S. dirigible Akron exploded just offsh...    7/12/1912 6:30
# 2  The first fatal airplane accident in Canada oc...    8/6/1913 00:00
# 3  The airship flew into a thunderstorm and encou...    9/9/1913 18:30
# 4  Hydrogen gas which was being vented was sucked...  10/17/1913 10:30

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2236, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2235 try:
# -> 2236     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2237     # If tzaware, these values represent unix timestamps, so we
#    2238     #  return them as i8 to distinguish from wall times
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# d:\Politeknik Negeri Malang\TI-3A\Semester 6\Big Data\uts\project-big-data-2023\uts.ipynb Cell 36 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/Politeknik%20Negeri%20Malang/TI-3A/Semester%206/Big%20Data/uts/project-big-data-2023/uts.ipynb#X54sZmlsZQ%3D%3D?line=0'>1</a> df['DateTime'] = pd.to_datetime(df['DateTime'])
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:1051, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1049         result = arg.map(cache_array)
#    1050     else:
# -> 1051         values = convert_listlike(arg._values, format)
#    1052         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py:402, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     400 assert format is None or infer_datetime_format
#     401 utc = tz == "utc"
# --> 402 result, tz_parsed = objects_to_datetime64ns(
#     403     arg,
#     404     dayfirst=dayfirst,
#     405     yearfirst=yearfirst,
#     406     utc=utc,
#     407     errors=errors,
#     408     require_iso8601=require_iso8601,
#     409     allow_object=True,
#     410 )
#     412 if tz_parsed is not None:
#     413     # We can take a shortcut since the datetime64 numpy array
#     414     # is in UTC
#     415     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2242, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2240         return values.view("i8"), tz_parsed
#    2241     except (ValueError, TypeError):
# -> 2242         raise err
#    2244 if tz_parsed is not None:
#    2245     # We can take a shortcut since the datetime64 numpy array
#    2246     #  is in UTC
#    2247     # Return i8 values to denote unix timestamps
#    2248     return result.view("i8"), tz_parsed
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:2224, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2222 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2223 try:
# -> 2224     result, tz_parsed = tslib.array_to_datetime(
#    2225         data.ravel("K"),
#    2226         errors=errors,
#    2227         utc=utc,
#    2228         dayfirst=dayfirst,
#    2229         yearfirst=yearfirst,
#    2230         require_iso8601=require_iso8601,
#    2231         allow_mixed=allow_mixed,
#    2232     )
#    2233     result = result.reshape(data.shape, order=order)
#    2234 except ValueError as err:
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:381, in pandas._libs.tslib.array_to_datetime()
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:613, in pandas._libs.tslib.array_to_datetime()
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:751, in pandas._libs.tslib._array_to_datetime_object()
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:742, in pandas._libs.tslib._array_to_datetime_object()
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\dateutil\parser\_parser.py:643, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     640 res, skipped_tokens = self._parse(timestr, **kwargs)
#     642 if res is None:
# --> 643     raise ParserError("Unknown string format: %s", timestr)
#     645 if len(res) == 0:
#     646     raise ParserError("String does not contain a date: %s", timestr)
#
# ParserError: Unknown string format: 12/21/1964 18.4

# %%
df.head()
# Out:
#         Date   Time                            Location  \
# 0 1908-09-17  17:18                 Fort Myer, Virginia
# 1 1912-07-12   6:30             AtlantiCity, New Jersey
# 2 1913-08-06  00:00  Victoria, British Columbia, Canada
# 3 1913-09-09  18:30                  Over the North Sea
# 4 1913-10-17  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary  Year  Total Death
# 0  During a demonstration flight, a U.S. Army fly...  1908          1.0
# 1  First U.S. dirigible Akron exploded just offsh...  1912          5.0
# 2  The first fatal airplane accident in Canada oc...  1913          1.0
# 3  The airship flew into a thunderstorm and encou...  1913         14.0
# 4  Hydrogen gas which was being vented was sucked...  1913         30.0

# %%
df['cn/In'].value_counts()
# Out:
# 6            8
# 1            7
# 178          6
# 55           6
# 4            6
#             ..
# 45652/176    1
# 22534        1
# 1114         1
# 19410        1
# 424          1
# Name: cn/In, Length: 3638, dtype: int64

# %%
df.head()
# Out:
#         Date   Time                            Location  \
# 0 1908-09-17  17:18                 Fort Myer, Virginia
# 1 1912-07-12   6:30             AtlantiCity, New Jersey
# 2 1913-08-06  00:00  Victoria, British Columbia, Canada
# 3 1913-09-09  18:30                  Over the North Sea
# 4 1913-10-17  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary  Year  Total Death
# 0  During a demonstration flight, a U.S. Army fly...  1908          1.0
# 1  First U.S. dirigible Akron exploded just offsh...  1912          5.0
# 2  The first fatal airplane accident in Canada oc...  1913          1.0
# 3  The airship flew into a thunderstorm and encou...  1913         14.0
# 4  Hydrogen gas which was being vented was sucked...  1913         30.0

# %% [markdown]
# # Years dan fatalities

# %%
plt.figure(figsize= (18, 8))
years = df['DateTime'].dt.year
_= plt.plot(df['Fatalities'], years, 'o')
_= plt.xlabel('Fatalities')
_= plt.ylabel('Years')
plt.show()

# %% [markdown]
# # Jumlah Kecelakaan per Tahun

# %%
year_count = df.groupby(df.DateTime.dt.year)[['Date']].count()

plt.figure(figsize= (18, 8))
plt.plot(year_count.index, year_count['Date'], marker= '.')

plt.xlabel('Years (Tahun)')
plt.ylabel('Jumlah Kecelakaan')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Politeknik Negeri Malang\TI-3A\Semester 6\Big Data\uts\project-big-data-2023\uts.ipynb Cell 43 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/Politeknik%20Negeri%20Malang/TI-3A/Semester%206/Big%20Data/uts/project-big-data-2023/uts.ipynb#X64sZmlsZQ%3D%3D?line=0'>1</a> year_count = df.groupby(df.DateTime.dt.year)[['Date']].count()
#       <a href='vscode-notebook-cell:/d%3A/Politeknik%20Negeri%20Malang/TI-3A/Semester%206/Big%20Data/uts/project-big-data-2023/uts.ipynb#X64sZmlsZQ%3D%3D?line=2'>3</a> plt.figure(figsize= (18, 8))
#       <a href='vscode-notebook-cell:/d%3A/Politeknik%20Negeri%20Malang/TI-3A/Semester%206/Big%20Data/uts/project-big-data-2023/uts.ipynb#X64sZmlsZQ%3D%3D?line=3'>4</a> plt.plot(year_count.index, year_count['Date'], marker= '.')
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'DateTime'

# %% [markdown]
# # survivors dan fatalities

# %%
sns.set_palette('pastel')
plt.figure(figsize=(12,10))
Aboard = df.Aboard.sum()
Fatalities = df.Fatalities.sum()
Survivors = Aboard - Fatalities

y = np.array([Fatalities, Survivors])
mylabels = ["Fatalities", "Survivors"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
df.head()
# Out:
#         Date   Time                            Location  \
# 0 1908-09-17  17:18                 Fort Myer, Virginia
# 1 1912-07-12   6:30             AtlantiCity, New Jersey
# 2 1913-08-06  00:00  Victoria, British Columbia, Canada
# 3 1913-09-09  18:30                  Over the North Sea
# 4 1913-10-17  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary  Year  Total Death
# 0  During a demonstration flight, a U.S. Army fly...  1908          1.0
# 1  First U.S. dirigible Akron exploded just offsh...  1912          5.0
# 2  The first fatal airplane accident in Canada oc...  1913          1.0
# 3  The airship flew into a thunderstorm and encou...  1913         14.0
# 4  Hydrogen gas which was being vented was sucked...  1913         30.0

# %%
for columnn in df.columns:                              
    if df[columnn].dtype == 'object':          
        try:                                        
            df[columnn] = pd.to_datetime(df[columnn])
        except ValueError:
            pass

# %%
df['Year'] = pd.DatetimeIndex(df['Date']).year

# %%
df.drop('DateTime',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Politeknik Negeri Malang\TI-3A\Semester 6\Big Data\uts\project-big-data-2023\uts.ipynb Cell 49 in 1
# ----> <a href='vscode-notebook-cell:/d%3A/Politeknik%20Negeri%20Malang/TI-3A/Semester%206/Big%20Data/uts/project-big-data-2023/uts.ipynb#Y103sZmlsZQ%3D%3D?line=0'>1</a> df.drop('DateTime',axis=1,inplace=True)
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\core\frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4809 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4810 def drop(
#    4811     self,
#    (...)
#    4818     errors: str = "raise",
#    4819 ):
#    4820     """
#    4821     Drop specified labels from rows or columns.
#    4822
#    (...)
#    4955             weight  1.0     0.8
#    4956     """
# -> 4957     return super().drop(
#    4958         labels=labels,
#    4959         axis=axis,
#    4960         index=index,
#    4961         columns=columns,
#    4962         level=level,
#    4963         inplace=inplace,
#    4964         errors=errors,
#    4965     )
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File d:\Aplikasi\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:6661, in Index.drop(self, labels, errors)
#    6659 if mask.any():
#    6660     if errors != "ignore":
# -> 6661         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662     indexer = indexer[~mask]
#    6663 return self.delete(indexer)
#
# KeyError: "['DateTime'] not found in axis"

# %%
df.head()
# Out:
#         Date   Time                            Location  \
# 0 1908-09-17  17:18                 Fort Myer, Virginia
# 1 1912-07-12   6:30             AtlantiCity, New Jersey
# 2 1913-08-06  00:00  Victoria, British Columbia, Canada
# 3 1913-09-09  18:30                  Over the North Sea
# 4 1913-10-17  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary  Year
# 0  During a demonstration flight, a U.S. Army fly...  1908
# 1  First U.S. dirigible Akron exploded just offsh...  1912
# 2  The first fatal airplane accident in Canada oc...  1913
# 3  The airship flew into a thunderstorm and encou...  1913
# 4  Hydrogen gas which was being vented was sucked...  1913

# %% [markdown]
# # crash per Tahun

# %%
plt.figure(figsize=(15, 5))
per_year_plot = sns.histplot(data = df, x = 'Year', bins = 100, color = "blue")
per_year_plot.set(title = "Fig. 1: Crashes per year")
fig = per_year_plot.get_figure()
fig.savefig('per_year_plot.png')

# %% [markdown]
# airplane type and fatalities

# %%
df_fatal = df.groupby('Type')[['Fatalities']].sum()
df_fatal
# Out:
#                                        Fatalities
# Type
# AAC-1 Toucan                                 23.0
# AEGK                                          5.0
# AT L98 Carvair                                4.0
# ATR 42-300                                    2.0
# ATR-42-300                                   46.0
# ...                                           ...
# de Havilland Dove 1                          22.0
# de Havilland Dragon 1                         3.0
# de Havilland RU-6A Beaver /Bell UH-1H        18.0
# de havilland Canada Twin Otter 200           11.0
# deHavilland DH-86                             9.0
#
# [2446 rows x 1 columns]

# %%
df_fatal = df_fatal.rename(columns={'Type': 'Fatalities'})
df_type_fatal = df_fatal.sort_values(by='Fatalities', ascending=False)
df_type_fatal_top10 = df_fatal.head(10) 
df_type_fatal_top10
# Out:
#                                   Fatalities
# Type
# AAC-1 Toucan                            23.0
# AEGK                                     5.0
# AT L98 Carvair                           4.0
# ATR 42-300                               2.0
# ATR-42-300                              46.0
# ATR-72-202                              16.0
# ATR-72-212                              68.0
# Aermacchi MB-339PAN (3 aircraft)         3.0
# Aero Commander  520                      6.0
# Aero Commander 500-B                     2.0

# %% [markdown]
# # airplane models dan crushes

# %%
plt.figure(figsize=(15, 5))
sns.barplot(y=df_type_fatal_top10.index, x="Fatalities", data=df_type_fatal_top10, palette="bright")
plt.xlabel('Total Fatalities')
plt.ylabel('Airplane Model')
plt.title('Total fatalities per airplane model')
plt.show()

# %%
airplanes = df[df['Fatalities'].notna()]
airplanes = df[df['Ground'].notna()]

# %%
df["Total Death"] = df["Fatalities"] + df["Ground"]
df.head()
# Out:
#         Date   Time                            Location  \
# 0 1908-09-17  17:18                 Fort Myer, Virginia
# 1 1912-07-12   6:30             AtlantiCity, New Jersey
# 2 1913-08-06  00:00  Victoria, British Columbia, Canada
# 3 1913-09-09  18:30                  Over the North Sea
# 4 1913-10-17  10:30          Near Johannisthal, Germany
#
#                  Operator          Route                    Type Registration  \
# 0    Military - U.S. Army  Demonstration        Wright Flyer III          NaN
# 1    Military - U.S. Navy    Test flight               Dirigible          NaN
# 2                 Private            NaN        Curtiss seaplane          NaN
# 3  Military - German Navy            NaN  Zeppelin L-1 (airship)          NaN
# 4  Military - German Navy            NaN  Zeppelin L-2 (airship)          NaN
#
#   cn/In  Aboard  Fatalities  Ground  \
# 0     1     2.0         1.0     0.0
# 1   NaN     5.0         5.0     0.0
# 2   NaN     1.0         1.0     0.0
# 3   NaN    20.0        14.0     0.0
# 4   NaN    30.0        30.0     0.0
#
#                                              Summary  Year  Total Death
# 0  During a demonstration flight, a U.S. Army fly...  1908          1.0
# 1  First U.S. dirigible Akron exploded just offsh...  1912          5.0
# 2  The first fatal airplane accident in Canada oc...  1913          1.0
# 3  The airship flew into a thunderstorm and encou...  1913         14.0
# 4  Hydrogen gas which was being vented was sucked...  1913         30.0

# %%
df_death_airline = df.groupby('Operator')[['Total Death']].sum() 
df_death_airline = df_death_airline.rename(columns={"Operator": "Total Death"})
df_death_airline = df_death_airline.sort_values(by='Total Death', ascending=False)
df_death_airline_top10 = df_death_airline.head(10)

df_death_airline_top10
# Out:
#                                  Total Death
# Operator
# Aeroflot                              7184.0
# American Airlines                     4310.0
# Military - U.S. Air Force             3866.0
# United Air Lines                      3770.0
# Air France                            1739.0
# Pan American World Airways            1322.0
# Military - U.S. Army Air Forces       1150.0
# AVIANCA                                944.0
# Turkish Airlines (THY)                 891.0
# Indian Airlines                        870.0

# %% [markdown]
# # Total Kematian per airplane crushes

# %%
plt.figure(figsize=(15, 5))
sns.barplot(y=df_death_airline_top10.index, x="Total Death", data=df_death_airline_top10, palette="pastel")
plt.xlabel('Total Death')
plt.ylabel('Airline Operator')
plt.title('Fig. 3: Total death per airline operator')
plt.show()
